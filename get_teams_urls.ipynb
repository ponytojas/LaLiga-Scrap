# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
short_url = 'https://www.bdfutbol.com/es/t/'
website = requests.get('https://www.bdfutbol.com/es/t/t2019-20.html').text

# %%
soup = BeautifulSoup(website,'lxml')

# %%
teams = soup.find('table',{'class':'taula_estil sortable'})

# %%
allTeams = []
teams1 = teams.findAll('tr', {'class': 'CHA'})
teams2 = teams.findAll('tr', {'class': 'UEF'})
teams3 = teams.findAll('tr', {'class': 'res'})
teams4 = teams.findAll('tr', {'class': 'prom_baixa'})

for team in teams1:
    allTeams.append(team)

for team in teams2:
    allTeams.append(team)

for team in teams3:
    allTeams.append(team)

for team in teams4:
    allTeams.append(team)

# %%
urls = []
names = []
for team in allTeams:
    url = str(team.findAll('a'))
    temp_url = re.search('/t/(.*)html', url)
    urls.append('https://www.bdfutbol.com/es/t/' + temp_url.group(1))
    temp_name = re.search('">(.*)</', url)
    names.append(temp_name.group(1))

# %%
df = pd.DataFrame(data={'URL': urls, 'Team': names})
# Out:
#                                           URL                Team
# 0    https://www.bdfutbol.com/es/t/t2019-201.           Barcelona
# 1    https://www.bdfutbol.com/es/t/t2019-202.         Real Madrid
# 2   https://www.bdfutbol.com/es/t/t2019-2059.             Granada
# 3    https://www.bdfutbol.com/es/t/t2019-207.  Atlético de Madrid
# 4   https://www.bdfutbol.com/es/t/t2019-2033.             Sevilla
# 5   https://www.bdfutbol.com/es/t/t2019-2030.       Real Sociedad
# 6   https://www.bdfutbol.com/es/t/t2019-2038.          Villarreal
# 7    https://www.bdfutbol.com/es/t/t2019-206.       Athletic Club
# 8   https://www.bdfutbol.com/es/t/t2019-2016.              Getafe
# 9   https://www.bdfutbol.com/es/t/t2019-2027.             Osasuna
# 10  https://www.bdfutbol.com/es/t/t2019-2020.             Levante
# 11  https://www.bdfutbol.com/es/t/t2019-2036.            Valencia
# 12  https://www.bdfutbol.com/es/t/t2019-2037.          Valladolid
# 13  https://www.bdfutbol.com/es/t/t2019-2047.               Eibar
# 14   https://www.bdfutbol.com/es/t/t2019-203.              Alavés
# 15   https://www.bdfutbol.com/es/t/t2019-208.               Betis
# 16  https://www.bdfutbol.com/es/t/t2019-2024.            Mallorca
# 17  https://www.bdfutbol.com/es/t/t2019-2011.       Celta de Vigo
# 18  https://www.bdfutbol.com/es/t/t2019-2014.            Espanyol
# 19  https://www.bdfutbol.com/es/t/t2019-2050.             Leganés

# %%
df.to_csv('teams.csv', sep= ';')
